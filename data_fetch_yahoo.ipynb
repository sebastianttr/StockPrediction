# %% [markdown]
# # Yahoo news Data fetch and save
#
# This notebook downloads all the data from the reuters about a specific topic and saves it to the database

# %%
import bs4
from bs4 import BeautifulSoup
import requests
import ray
from math import ceil
import time
from datetime import datetime
from http.client import HTTPSConnection
from urllib.parse import urljoin, unquote
import re
from time import sleep
import datetime;

# %%
num_cpus = 4

ray.init(ignore_reinit_error=True, num_cpus=num_cpus)
# Out:
# 2024-06-18 17:14:56,937	INFO worker.py:1558 -- Calling ray.init() again after it has already been called.
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.8.18', ray_version='2.9.3', ray_commit='62655e11ed76509b78654b60be67bc59f8f3460a', protocol_version=None)

# %%
import duckdb

class NewsMetaRepository:
    def __init__(self, csv_file=None):
        self.connection = duckdb.connect(database=':memory:', read_only=False)
        self._create_table()
        if csv_file is not None:
            try:
                self.connection.execute(f"IMPORT DATABASE '{csv_file}';")
            except Exception as e:
                print(e)
                # If it does not exist, create a new one
                self.connection.execute(f"EXPORT DATABASE '{csv_file}';")

    def _create_table(self):
        self.connection.execute("CREATE TABLE news_meta (id VARCHAR, title VARCHAR UNIQUE, url VARCHAR, timestamp VARCHAR UNIQUE,source VARCHAR)")
        self.connection.execute("CREATE SEQUENCE id_sequence START 1 INCREMENT BY 1;")

    def insert(self, news_meta):
        print(news_meta['title'])
        self.connection.execute("PREPARE insert_meta AS "
                                "INSERT INTO news_meta VALUES (nextval('id_sequence'), ?, ?, ?, ?) ON CONFLICT DO NOTHING;")
        self.connection.execute(f"EXECUTE insert_meta('{news_meta['title']}', '{news_meta['url']}', '{news_meta['timestamp']}', '{news_meta['source']}');")

    def select_all(self):
        return self.connection.execute("SELECT * FROM news_meta").fetchdf()

    def select_by_id(self, id):
        return self.connection.execute("SELECT * FROM news_meta WHERE id = ?", id).fetchdf()

    def select_by_title(self, title):
        return self.connection.execute("SELECT * FROM news_meta WHERE title = ?", title).fetchdf()

    def select_by_url(self, url):
        return self.connection.execute("SELECT * FROM news_meta WHERE url = ?", url).fetchdf()

    def select_by_date(self, date_from, date_to):
        return self.connection.execute(f"SELECT * FROM news_meta WHERE strptime(timestamp, '%Y-%m-%dT%H:%M:%S%z') BETWEEN strptime('{date_from}','%Y-%m-%d') AND strptime('{date_to}','%Y-%m-%d')").fetchdf()

    def delete_all(self):
        self.connection.execute("DELETE FROM news_meta")

    def export(self, csv_file):
        self.connection.execute(f"EXPORT DATABASE '{csv_file}';")

    def close(self):
        self.connection.close()

# %%
def try_request(url, headers, params):

    # resp_proxy = requests.get('https://free-proxy-list.net/')
    # df = pd.read_html(resp_proxy.text)[0]
    # df_http = df[df['Https']=='no']
    # df_https = df[df['Https']=='yes']
    # proxy_http = f'https://{df_http["IP Address"].values[0]}:{df_http["Port"].values[0]}'
    # proxy_https = f'https://{df_https["IP Address"].values[0]}:{df_https["Port"].values[0]}'

    proxies={
        "http": 'socks5://193.35.18.30:30808',
        "https": 'socks5://193.35.18.30:30808'
    }

    response_page = requests.request("GET", url, headers=headers, params=params, timeout=5)
    try:
        response = response_page.text

        if response_page.status_code > 300:
            print("Status code error: " + str(response_page.status_code))
            return False, params

        return True, response
    except requests.exceptions.JSONDecodeError as e:
        print(f"Bad Request: GET {url} \n Status Code: {response_page.status_code} | Error : {e}")
        return False, params
    except requests.exceptions.Timeout:
        print("Timed out")
        return False, params
    except requests.exceptions.RequestException as e:
        print(f"Bad Request: GET {url} \n")
        return False, params

def get(host, url, payload, headers):
    connection = HTTPSConnection(host)
    connection.request('GET', url, payload, headers)

    response = connection.getresponse()
    location_header = response.getheader('location')

    if response.status < 400:
        if location_header is None:
            return 200, response.read()
        else:
            location = urljoin(url, location_header)
            return get(host, location, payload, headers)
    else: return response.status, None

# %%
headers = {
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9',
    'referer': 'https://www.google.com',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36 Edg/85.0.564.44'
}

newsMetaRepository = NewsMetaRepository('meta/yahoo')

def get_article(card):
    """Extract article information from the raw html"""
    headline = card.find('h4', 's-title').text
    source = card.find("span", 's-source').text
    posted = card.find('span', 's-time').text.replace('·', '').strip()
    description = card.find('p', 's-desc').text.strip()
    raw_link = card.find('a').get('href')
    unquoted_link = requests.utils.unquote(raw_link)
    pattern = re.compile(r'RU=(.+)\/RK')
    clean_link = re.search(pattern, unquoted_link).group(1)

    article = (headline, source, posted, description, clean_link)
    return article

def get_article_clean_link(link):
    pattern = re.compile(r'RU=(.+)\/RK')
    url_clean_re_group = re.search(pattern, link)
    if url_clean_re_group is not None:
        return unquote(url_clean_re_group.group(1))
    else:
        return link


# ct stores current time
ct = datetime.datetime.now()

def get_news_meta(search_term):
    template = 'https://news.search.yahoo.com/search?p={}'
    url = template.format(search_term)
    articles_titles = set()
    
    page = 0

    while True:
        page += 1
        print(f"Page {page}")
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        cards = soup.find_all('div', 'NewsArticle')

        # extract articles from page
        for card in cards:
            try:
                article_element: bs4.PageElement = card.find('li')
                article_title = ''
                if article_element.find('a', 'thmb ') is None:
                    article_title = article_element.find('h4').text
                else :
                    article_title = article_element.find('a')['title']
                                
                if article_title not in articles_titles:
                    articles_titles.add(article_title)
                    article_source = card.find("span", 's-source').text.replace("'", "''")
                    article_posted = card.find('span', 's-time').text.replace('·', '').strip()
                    article_url = get_article_clean_link(article_element.find('a')['href'])
                    article_title = article_title.replace("'", "''")
                                         
                    news_meta = {
                        'title': article_title,
                        'source': article_source,
                        'timestamp': datetime.datetime.now(), # change this to something else 
                        'url': article_url
                    }
                    newsMetaRepository.insert(news_meta)
                    
            except Exception as e:
                print('Error: ', e.with_traceback())
                break
        try:
            url = soup.find('a', 'next').get('href')
        except AttributeError:
            break
        
    print(f'Size of articles:' + str(len(articles_titles)))
    newsMetaRepository.export("meta/yahoo")
        
    newsMetaRepository.close()

articles = get_news_meta('Tesla')
# Out:
# Catalog Error: Sequence with name "id_sequence" already exists!
# Page 1
# TSLA Stock Alert: Tesla Sues Battery Supplier Matthews International
# The Tesla Model Y Takes Top Spot in American-Made Index Yet Again
# Gateway - Quartz
# Tesla China Registrations Are Down 9% With Two Weeks Remaining In Q2
# A Tesla in Full Self-Driving mode crashed into a cop car that was already responding to a deadly car...
# Tesla Cybertruck Deliveries Reportedly Halted Due To Safety Issue
# Tesla topped an annual list of the most made-in-America vehicles for the third straight year
# Tesla Lags Behind Mag 7 — Will Master Plan 4 Spark A Comeback? - Tesla (NASDAQ:TSLA)
# Tesla Model Y Is Once Again The Most American-Made Car
# Column: Elon Musk thinks Tesla''s investors love him. He''s very wrong
# Page 2
# Gateway - Jalopnik
# Tesla Master Plan 4 = Anything But Cars - Morgan Stanley By Investing.com
# Tesla Model 3 LR AWD Now Qualifies for $7,500 Point of Sale EV Tax Credit - EconoTimes
# Tesla sues ex-supplier Matthews over EV battery trade secrets
# Page 3
# Matthews International fires back after Tesla files lawsuit in California
# Tesla’s big, epic, confusing future
# Tesla, Inc. (NASDAQ:TSLA) Shares Bought by Brown Shipley& Co Ltd
# EV stocks trade mostly lower in the wake of Fisker’s bankruptcy
# Tesla, Inc. (NASDAQ:TSLA) Shares Purchased by Spartan Planning & Wealth Management
# Tesla developing stock-based compensation for high-performing employees - Reuters By Investing.com
# Tesla slips in Cars.com American-Made Index as Jeep, Toyota rise
# Page 4
# Tesla reaches surprising milestone with one of its latest models: ''Achieved without sacrificing...
# Elon Musk''s Pay Package Is One More Reason to Sell Tesla Stock
# Tesla, Inc. (NASDAQ:TSLA) Shares Acquired by ICA Group Wealth Management LLC
# Elon Musk Lures Tesla Employees With Stock Awards After His $56B Pay Package Receives Shareholder...
# Elon Musk Says He Is Working On Tesla''s New Master Plan: ''It Will Be Epic'' - Tesla (NASDAQ:TSLA)
# Ables Iannone Moore & Associates Inc. Takes $776,000 Position in Tesla, Inc. (NASDAQ:TSLA)
# Elon Musk''s gamer streams are a new way to hear him riff on Tesla, SpaceX, and Neuralink
# Page 5
# Bankruptcy at Tesla Rival Fisker Highlights a Risk for Chip Makers. And 4 Other Things to Know...
# Tesla sells out of its most expensive liquor yet — a $450 bottle of mezcal
# Tesla sued its former supplier for stealing EV battery trade secrets
# Musk plans stock option grants to Tesla''s high-performers, sources say
# Tesla, Inc. (TSLA) Is a Trending Stock: Facts to Know Before Betting on It
# Tesla launches $1B suit against former supplier Matthews for stealing battery trade secrets By...
# Musk plans stock option grants to Tesla''s high-performers, sources say By Reuters
# These Stocks Are Moving the Most Today: Micron, Tesla, Silk Road, Boeing, Lennar, La-Z-Boy, Chegg,...
# Page 6
# Fisker Files for Bankruptcy After EV Stock Bubble Bursts. It Couldn’t Rival Tesla.
# Tesla kicks off legal fight to reinstate Musk''s pay
# Tesla Sues Former Supplier Over Trade Secret Theft, Seeks $1B Compensation: Report - Tesla...
# 5 surprises from Tesla''s high-stakes shareholders meeting
# Tesla Model 3 Long Range Now Qualifies For Full $7,500 Tax Credit - Tesla (NASDAQ:TSLA)
# Tesla renews legal fight to reinstate Elon Musk’s $56B pay package after shareholders back deal
# Tesla Sues EV-Battery Supplier Over Alleged Disclosure of Trade Secrets
# Tesla defends its lead in American-Made Index; Honda and VW models close in
# Page 7
# What''s Driving Tesla Inc''s Surprising 11% Stock Rally?
# Tesla Crashes Into Police Cruiser Already Responding To Fatal Car Crash While In Full Self Driving...
# Tesla Cuts Prices On Select Variants Of Model 3 In Canada - Tesla (NASDAQ:TSLA)
# Tesla Advances on Multiple Fronts Despite Volatility | Investing.com Canada
# Tesla''s Tariff Problem Has Just Begun
# Musk Plans Stock Option Grants to Tesla''s High-Performers, Sources Say
# ...Prediction About Humanoid Robots: ''They Will Be 10X More Common Than Cars'' - NVIDIA...
# Page 8
# Tesla sues ex-supplier Matthews over EV battery trade secrets By Reuters
# Tesla Model 3 Long Range Appears To Be Eligible For The $7,500 Tax Credit
# ''Irreparable Harm'': Tesla Sues Supplier For Stealing $1 Billion Battery Secrets
# Tesla’s $20,000 EV Might Be a Stripped-Down Version of Its Best-Selling Car
# Tesla rival Fisker files for bankruptcy
# Tesla is the biggest stock bubble in history and shares are headed to $15, short seller says
# Tesla Cybertruck Deliveries Halted Amid Windshield Wiper Issue; Watch Elon’s Victory Lap -...
# Page 9
# Tesla Gets Shanghai Approval to Test Advanced Driver Assistance
# Tesla, Broadcom Among S&P 500 Stock Winners Monday. First Solar Leads Losers.
# How The SEC''s Latest Elon Musk Investigation Could Hit Tesla
# Tesla board restores Musk’s $44B pay | Northwest Arkansas Democrat-Gazette
# Tesla''s Boardroom Dynamics Could Impact Its Stock Performance Amidst CEO Elon Musk''s Record-Breaking...
# Tesla Sues Ex-Supplier Matthews International Corp. for Stealing EV Battery Trade Secrets | The...
# Tesla Shareholders Upheld Elon Musk’s $48 Billion Pay Deal. Now What? - Tech News Briefing - WSJ...
# Page 10
# Canada''s EV rebate program hits record as Tesla dominates claims
# Tesla’s Battle Over Elon Musk’s Pay Package Could Slow Its Growth
# Tesla rejected a new anti-harassment policy days before Elon Musk sued for sexual harassment at...
# Tesla shareholders approve Elon Musk’s massive compensation package
# Tesla reportedly delays Cybertruck deliveries because of windshield wiper issues
# Page 11
# Tesla sues ex-supplier Matthews over EV battery trade secrets; supplier calls it bullying
# Tesla Stock Rises. How High It Could Climb Today.
# The rare Tesla lawsuit where the company is the plaintiff.
# Tesla Investors Get Behind Musk’s Fight for $56 Billion Pay Deal
# Tesla Shareholders Approve Elon Musk''s $56 Billion Pay Package, Move Incorporation to Texas
# Tesla Robotaxi Next After Huge Elon Musk Pay Deal; BYD Near Buy Point As Sales Rev
# Tesla gets Shanghai approval to test advanced driver assistance
# Tesla and Baidu Partner for Full Self-Driving Test
# Tesla Cybertruck Joins Dubai Police Supercar Fleet: Elon Musk Calls It ''Cool'' - Tesla (NASDAQ:TSLA)
# Page 12
# Tesla kicks off legal fight to reinstate Musk''s pay By Reuters
# Tesla board restores Musk’s $44B pay | Arkansas Democrat Gazette
# Tesla kicks off legal fight to reinstate Musk’s pay
# Page 13
# Tesla Cybertrucks Are Still Breaking Down All Of The Time
# Tesla Extends FSD Transfers for Another Quarter, Confirms Elon Musk - EconoTimes
# Page 14
# Tesla launches $1B suit against former supplier Matthews for stealing battery trade secrets
# Tesla investors back $56bn Musk pay deal
# Tesla Model 3 And Cybertruck Top Used Car Listings—But At Opposite Price Extremes
# Tesla shareholders strongly support Elon Musk''s $44.9-billion pay package
# Tesla Ramping Up Cybertruck Production To Touch 2,500 Units Per Week: Non-Foundation Series To Start...
# Tesla shareholders back huge payout for CEO Musk, company says | Fox 11 Tri Cities Fox 41 Yakima
# Tesla shareholders re-approve Elon Musk’s $44.9 billion pay package
# Page 15
# Tesla Analyst Explains Why EV Maker Is ''Going To Prove To Be The Next Enron'': ''Many Fanboys Will Run...
# Tesla shareholders back huge payout for CEO Musk, company says
# Tesla shareholders sue Musk for starting competing AI company
# Tesla shareholders vote to reinstate Musk''s $56B pay package
# Tesla''s Pay Package Incentivizes the Wrong Thing
# Tesla Jumps After Musk Says Shareholders Backed Pay Package
# Tesla shareholders approve Elon Musk''s $56B pay package
# Tesla Sues Ex-Supplier Matthews Over EV Battery Trade Secrets
# Tesla Investors Back Musk’s $56 Billion Pay Deal, Texas Move (3)
# Page 16
# Tesla Releases Results of 2024 Annual Meeting of Stockholders
# Tesla Shareholders Approve Elon Musk $56B Pay Package, Other Company Proposals - Tesla (NASDAQ:TSLA)
# Tesla investors approve Elon Musk''s $55 billion pay plan
# Page 17
# Tesla Analyst Explains Why EV Marker Is ''Going To Prove To Be The Next Enron'': ''Many Fanboys Will...
# Tesla, Inc. (NASDAQ:TSLA) is V Square Quantitative Management LLC’s 5th Largest Position
# Tesla CEO Elon Musk Eyes $25 Trillion Market Cap With Optimus Bot, Admits To Being ''Pathologically...
# Tesla shareholders re-approve Elon Musk’s $50 billion pay package
# Tesla''s Largest Outside Investor Vanguard''s Vote Switch Helped Pass Elon Musk''s $56B Pay Package - ...
# Tesla Shareholder Meeting Starts, Musk Pay Package Approved
# Tesla driver says he was using ‘self-drive’ system when his car hit a parked police vehicle
# Tesla Shareholders Vote No on Deep Sea Mining Moratorium
# Tesla''s scare tactics worked to win shareholder approval of Elon Musk''s pay, but problems remain
# Tesla Bull Adam Jonas Thinks Tesla Will Make A Phone; Elon Musk Hopes It Won''t Be Needed - Tesla...
# Page 18
# Tesla, Inc. (NASDAQ:TSLA) Shares Sold by WNY Asset Management LLC
# ''Tesla Is Musk, Musk Is Tesla.'' Former Ford CEO Warns Of Significant Talent Drain If The CEO Leaves.
# Tesla (NASDAQ:TSLA) Trading 2.7% Higher
# Page 19
# Tesla Shareholders Reject Deep Sea Mining Moratorium As Global Environmental Debate Continues - ...
# Tesla Shareholders Back Huge Payout for CEO Musk, Company Says
# ''Tesla Is Musk, Musk Is Tesla,'' Dan Ives Emphasizes Ahead Of Shareholder Vote; Former Ford CEO Warns...
# Tesla investors sue Elon Musk for diverting resources, talent to xAI
# Tesla’s Elon Musk Is Getting His Money. What Happens Next.
# Tesla expects to raise price of Model 3 in EU as bloc preps import duties on cars made in China
# Tesla (NASDAQ:TSLA) Stock Rating Reaffirmed by Cantor Fitzgerald
# Tesla shareholders approve Elon Musk''s massive pay package, but legal fight ''far from over''
# Tesla’s scare tactics to approve Elon Musk’s pay worked, but problems remain
# Page 20
# Tesla Investors Back Musk’s $56 Billion Pay Deal, Texas Move
# Tesla’s (TSLA) “Outperform” Rating Reiterated at Wedbush
# Tesla Says Optimus Bots Are Now Performing Autonomous Tasks At Its Factory, 3 Years After...
# Tesla Shareholders Approve Musk''s Massive $56 Billion Pay Package
# Tesla Investor Relations Chief Martin Viecha to Depart After Annual Shareholder Meeting, Elon Musk...
# Tesla must face autopilot false ad claims by California DMV
# Page 21
# Tesla shareholders vote on $44.9B CEO payday; Starbucks gets favorable union ruling
# Tesla Stock Rises in Premarket Trading After Shareholders Back Musk''s Pay Package
# Tesla driver using self-driving mode slammed into police cruiser in Orange County
# Tesla Robotaxi Revenue Is Likely Years Away, JPMorgan Warns
# Page 22
# Tesla shareholders approve CEO Elon Musk’s $45bn pay package
# Video shows Tesla crash into parked police car while in self-driving mode in California
# Page 23
# Page 24
# Page 25
# Tesla shareholders want Elon Musk to get his billions. What comes next?
# Tesla shareholders re-approve Elon Musk’s pay package worth billions that a judge struck down
# Tesla''s performance since Musk''s compensation package was first approved in 2018
# Tesla shareholders approve CEO Elon Musk''s $56 billion pay package
# Tesla driver tells police he was using ''self-drive'' system when his car hit a parked police vehicle
# Tesla shareholders vote to give Elon Musk a $56 billion pay package after a court shot it down
# Page 26
# Trending tickers: Apple, Palantir, Tesla and Whitbread
# Tesla dealership building in Lake Elmo sells for millions - Minneapolis / St. Paul Business Journal
# Tesla investors sue Elon Musk for diverting carmaker’s resources to xAI
# Tesla Shareholders Meeting 2024 Preview: How To Watch, Elon Musk Compensation Package Explained,...
# Tesla has put 2 Optimus robots to work on its factory floor
# Page 27
# Tesla Stock Headed for Its Highest Close Since April
# Tesla in ''self-drive'' mode crashes into Fullerton police vehicle
# Tesla shareholders vote to reinstate Elon Musk’s $56 billion pay package
# Tesla shareholders vote yes again to approve Elon Musk’s $56B pay plan | TechCrunch
# Tesla shareholders vote to restore big pay package for Musk that court voided
# Page 28
# Tesla’s Superchargers are changing the game for Rivian and Ford’s EVs
# Tesla (TSLA) to Hike Model 3 Prices in Europe on Higher Tariff
# Tesla Vote Lifts Cloud Off Stock Even as Deeper Woes Lie Ahead
# Tesla stock soars as shareholders seemingly approve Elon Musk''s supersized pay package
# Page 29
# Tesla shareholders re-approve Elon Musk’s pay package worth billions that a judge struck down -...
# Page 30
# Tesla Shareholders Back Huge Payout For CEO Musk, Company Says
# Tesla Shareholders Backed Musk’s Pay Deal. Here''s What''s Next
# Tesla Driver Tells Police He Was Using ''Self-Drive'' System When His Car Hit a Parked Police Vehicle
# Tesla Delays Cybertruck Deliveries Due to Windshield Wiper Issue
# Tesla Breaks Trend, Tests Key Support Level Ahead Of Musk Pay Vote
# Retail sales ahead, Tesla''s legal fight over Musk pay deal - what''s moving markets
# Page 31
# Page 32
# Tesla reported to police in Sweden over alleged illegal electrical work
# Tesla to raise prices in wake of EU crackdown on Chinese electric cars
# Retail sales ahead, Tesla''s legal fight over Musk pay deal - what''s moving markets By Investing.com
# Page 33
# Tesla China Registrations Slip Even As Analysts See A Stronger Q2
# Woody Harrelson details motorcycle accident that caused him go over handlebars: ''There was some pain...
# Tesla shareholders re-approve Elon Musk’s pay package worth billions that a judge struck down - KVIA
# Page 34
# Tesla''s latest product can slash your home energy bills by $1,500 a year — here''s how much it costs...
# Tesla investors sue Elon Musk for launching a rival AI company
# Page 35
# S&P 500 Hangs Near Record High
# Tesla May Raise Model 3 Price in Europe Due to EU Tariffs on EVs From China
# Tesla pay fight tests power of Elon Musk''s mystique
# Tesla shareholders re-approve Elon Musk’s pay package worth billions that a judge struck down | CNN...
# Forget Elon Musk’s record pay package from Tesla. More could be on the way. | CNN Business
# Indonesia''s $5 billion deal with Tesla is only part of its all-in strategy on nickel mining
# Page 36
# These Stocks Are Moving the Most Today
# Why Tesla Stock Is Shooting Higher In Today''s Premarket - Tesla (NASDAQ:TSLA)
# Tesla driver tells police he was using ''self-drive'' system when his car hit a parked police vehicle...
# Tesla Resumes Hiring: AI And Robotics Engineers, Service Technician Jobs Open
# ... Spells More Trouble Than The Other, Say Experts: ''Be Careful What You Wish For'' - Tesla...
# Tesla Stock Takes Off as Musk Says His $56B Pay Deal Will Be Approved
# Tesla shareholders have approved Elon Musk’s ''unfathomable'' pay package
# Page 37
# Tesla to Replace Diesel-Electric Trains With Battery-Electric Models on Berlin Shuttle Service
# Tesla, Two AI Plays Lead S&P 500 Winners Monday
# Tesla’s Nordic Shareholders Seek to Promote Workers’ Rights in Vote
# Tesla Cybertruck Deliveries Delayed Because Of Big Ass Wiper
# Tesla and its fans waged an unprecedented battle over Elon Musk''s $56B pay package
# Page 38
# Forget Elon Musk’s record pay package from Tesla. More could be on the way.
# Big Hair bands lined up for next Monsters of Rock cruise
# Tesla ''Not Going To Grow This Year,'' Says Bernstein Analyst: Maintains ''Underweight'' Rating While...
# Page 39
# Tesla shareholders approve $46 billion pay package for CEO Elon Musk
# Tesla’s FSD Fleet Hits Shanghai: 10 Cars Set for Pilot Ahead of Public Debut - EconoTimes
# Tesla''s stock should hit $2,600 in five years, says Cathie Wood''s Ark Invest
# Ted Danson Treats Woody Harrelson''s Wounds After Motorcycle Accident En Route to a Podcast Interview
# Page 40
# Ted Danson Treats Woody Harrelson''s Wounds After Motorcycle Accident
# Tesla''s Musk wins shareholder approval for $56 billion pay package, touts his ability to ''deliver''
# ''We love Elon'': Tesla shareholders bask in CEO''s presence
# Tesla shareholder sues Musk to return billions in alleged unlawful profits
# Page 41
# Tesla to Discontinue Foundation Series Cybertruck, New Models and Global Versions on the Horizon -...
# Tesla Shares Jump Premarket After Musk Says Vote on Pay Package Winning by Wide Margins
# Tesla Shareholders Vote To Reapprove Elon Musk’s Massive Pay — But Courts May Thwart Him From Raking...
# Page 42
# Elon Musk’s Latest Legal Challenge Isn’t a Tesla Issue
# Tesla shareholders approve Elon Musk pay package rejected by court
# Matthews International fires back after Tesla files lawsuit in California - Pittsburgh Business...
# Page 43
# Tesla expects to raise price of Model 3 in the European Union over import duties
# Tesla plans to leverage Elon Musk''s big pay win in Delaware court battle
# Elon Musk''s $56B Payday Wins In Landslide: ''Next Chapter In The Tesla Growth Story'' - Tesla...
# Tesla Musk Pay
# Page 44
# Opinion | Tesla is now Musk’s dream factory
# How Tesla CEO Elon Musk Won His Pay Back
# Page 45
# Indonesia’s $5 billion deal with Tesla is only part of its all-in strategy on nickel mining
# Tesla just tied the knot with Elon Musk, for better or worse. (Probably worse).
# Tesla Expects to Raise Model 3 Price Due to EU Tariffs on EVs From China
# Tesla in self-drive mode slams into police car in Orange County
# U.S. government assails Adobe for putting up ''wholly unnecessary'' roadblocks when subscribers try to...
# Page 46
# Tesla''s Top Rival BYD Unveils Latest EV Model Under Fang Cheng Bao Lineup: Report
# Tesla CEO Musk''s Pay Package Gets Support From 77% of Votes at Investor Meet
# NEC Solution Innovators, Ltd. Sales Division Selects Xactly to Accelerate Sales Forecasting
# It’s official: Tesla shareholders grant Elon Musk the biggest executive pay package in US history
# HumanPlus: Robot that learns boxing, playing piano by watching people
# Page 47
# Tesla receives approval to build massive new factory to produce Megapack batteries: ''Leading to...
# Tesla Stock Rallies To 2-Month High As Musk’s $50 Billion Pay Package ‘Overhang’ Fades
# Tesla''s New Version Of ''Full Self-Driving'' Is Better, But Flawed
# Tesla In Last-minute Shareholder Sprint For Huge Musk Pay Package
# Page 48
# Tesla Expects to Raise Price of China-Made Cars in EU After Duty Increase
# Tesla to Increase Model 3 Prices in Europe as Higher Chinese Tariffs Take Effect
# Tesla stockholders vote to restore Elon Musk''s record $44.9 billion pay package that was tossed out...
# Tesla (TSLA) Stock Dips While Market Gains: Key Facts
# Interactive Brokers chief strategist says Broadcom should replace Tesla in Magnificent 7 - CNBC By...
# Page 49
# Tesla service center bought for $11M - St. Louis Business Journal
# Tesla driver tells police he was using ‘self-drive’ system when his car hit a parked police vehicle
# Page 50
# This vehicle is No.1 again on the American-Made Index
# Page 51
# Tesla shareholder meeting: How investors are voting on Musk''s $56-bln pay package
# Tesla is making progress on its sustainability goals.
# Tesla Shareholders Approve Elon Musk''s $56 Billion Pay Package
# Page 52
# Tesla expects to raise price of China-made cars in EU after duty increase
# Great News for Tesla, So Why Is the Stock Down?
# Page 53
# ...Delaware With Farewell Cake After Shareholders Approve Move To Texas: ''Vox Populi, Vox Dei'' - ...
# Elon Musk convinced Tesla investors to back his pay. Now he must persuade a judge.
# Tesla stock soars as shareholders seemingly approve Elon Musk’s supersized pay package
# True Tesla Technologies Secures Provisional Energy Generation Permit in Mauritius
# Should Tesla’s Inventory Pileup Worry Investors?
# Napa Wealth Management Invests $357,000 in Tesla, Inc. (NASDAQ:TSLA)
# NVDA Stock Alert: SCOTUS Will Hear Nvidia Case Over Shareholder Lawsuit
# Page 54
# Page 55
# Tesla shareholders approve Elon Musk''s $56bn pay package
# Tesla in self-driving mode plows into police car as officer investigates separate deadly crash in OC
# Page 56
# Tesla plans to leverage Elon Musk''s big pay win in Delaware court battle By Reuters
# A lot full of Teslas in Scottsdale has people wondering what''s going on
# Tesla''s Autopilot spat with Cali DMV must go to trial: Judge
# Page 57
# Tesla Investors Voted For Elon Musk''s $45 Billion Pay Package, But He Won''t Get It Yet
# Tesla Shareholders Rush To Sue Elon Musk Before The Company Moves To Texas
# Meet one of America''s first Tesla Cybertruck owners, and he lives in Columbia County
# Tesla shareholders approve Elon Musk’s $56B pay package
# Tesla Bear Says Elon Musk Has ''Mentally Checked Out'' Of EV Giant Long Ago, But Will Stay Back For...
# Page 58
# Tesla shares up after Elon Musk says he is set for victory in $56 billion pay vote
# Nvidia Beware: Bankruptcy at Tesla Rival Fisker Highlights This Risk for Chip Makers.
# Tesla’s 2024 shareholder meeting is underway.
# Tesla''s Musk Pay Package Vote Lifts Cloud Off Stock
# Tesla says it has two humanoid robots working on its factory floor
# Page 59
# ...s Surprising Stance On EVs, Says Former President Is ''Huge Fan'' Of The Tesla Cybertruck - Tesla...
# ‘Tunes and the tide:’ Heavy metal cruise to set sail from Miami
# Tesla Crashes Into Police Car While in Self-Driving Mode
# Page 60
# How Elon Musk''s $44.9B Tesla pay package compares with the most generous plans for other U.S. CEOs
# Tesla probably won''t make money from self-driving robotaxis for years, JPMorgan says
# How to watch Tesla’s annual stockholder meeting
# Tesla''s performance since Musk''s compensation package was first approved in 2018 By Reuters
# Stock Market Today: S&P 500, Nasdaq Set to Open Up, Dow Flat; Nvidia, Broadcom, Tesla, GameStop, and...
# Page 61
# Tesla in last-minute shareholder sprint for huge Musk pay package
# Tesla Stock Will Ride Higher on Musk’s Pay Raise. Plus, GM, Warner Bros., and More.
# Tesla''s self-driving issues mount in CA - Silicon Valley Business Journal
# Tesla Bull Gary Black Sees Elon Musk''s $56B Pay Package Pass ''Easily'' At Shareholder Meeting;...
# Page 62
# Opinion: Elon Musk allegations remind us that sexual harassment is about power
# Tesla rises premarket after Musk says shareholders voting yes on $56 bn pay plan
# Tesla Cybertruck Police Vehicle revealed
# Tesla stock soars after Elon Musk says his pay package is likely to be approved and BlackRock and...
# Is Tesla Stock A Buy Or A Sell With Elon Musk''s Pay Package Expected To Pass By ''Wide Margins''?
# Tesla Presses EU for Lower Tariff on EVs Shipped in From China
# Tesla shareholders approve Elon Musk''s $56 billion pay package
# Page 63
# Musk Pay Victory Removes Cloud at Tesla, but Fresh Legal Fight Looms
# Tesla shareholders back Musk pay package, Adobe''s outlook - what''s moving markets
# Watch Tesla''s 2024 Shareholder Meeting Here
# Tesla Investors to Decide if Musk Deserves $45 Billion Payday
# Tesla shareholders vote to reapprove Elon Musk’s massive pay — but courts may thwart him from raking...
# ...56B Pay Package Now Needs Green Signal From Delaware Judge Who Earlier Voided It: Report - Tesla...
# Meet one of America''s first Tesla Cybertruck owners, and he lives in Augusta area
# Page 64
# Tesla Shareholder Sues Musk to Return Billions in Alleged Unlawful Profits
# Jim Chanos Scoffs At Elon Musk''s Claim About Tesla Hitting $30 Trillion+ Market Cap: ''So 30% Of...
# Musk Officially Shifts Tesla Incorporation to Texas After Vote
# Apple And Tesla Supplier TDK Announces Solid-State Battery Breakthrough, CEO Says It Can Make...
# Future of Elon Musk and Tesla are on the line as shareholders vote on massive pay package
# Page 65
# Worried About Market Volatility? Benzinga''s SmallCAP Event Has Answers
# Here''s How Much You Would''ve Lost If You Bought Dogecoin During Elon Musk''s Appearance On SNL
# Page 66
# Elon Musk wins back his huge Tesla payday in shareholder vote
# Interactive Brokers chief strategist says Broadcom should replace Tesla in Magnificent 7 - CNBC
# Q Precious & Battery Metals Corp. Receives Permits to Drill VMS and Lithium Pegmatite Targets La...
# Future of Elon Musk and Tesla are on the line this week as shareholders vote on massive pay package...
# Page 67
# Bitcoin uses more renewable energy, but will Tesla accept it again?
# Tesla Stock Rebound Lifts Cathie Wood’s ARK Innovation. It Isn’t Enough.
# Page 68
# Scarborough Advisors LLC Raises Holdings in Tesla, Inc. (NASDAQ:TSLA)
# Tesla CEO Musk''s pay package gets support from 77% of votes at investor meet
# Musk answers Tesla faithful with trillion-dollar robot prophesy
# Dow Jones, S&P 500 Open Little Changed On Soft Retail Sales; Nvidia, Super Micro Rise
# New Intermountain Health Layton Ambulatory Surgery Center Improves Access to Lower-Cost Procedures
# Tesla Can’t Be All About Elon Musk
# Shareholders say they''re OK with Elon Musk''s Tesla pay
# Page 69
# Tesla Shareholders Vote on Musk''s Historic Pay Package
# Tesla shareholder meeting: How investors are voting on Elon Musk''s $56 billion pay package
# Tesla Investors Are Suing Elon Musk for Creating Rival AI Company
# 2024 Tesla Model 3, Information and Specs
# Alert: Tesla stockholders vote to restore Elon Musk''s record $44.9 billion pay package that was...
# Page 70
# AI-Powered Business Content: Marketing Copy & Blog Creation Platform Announced
# Tesla could get special duties as part of higher China EV tariffs, EU says
# Lifequests Wholly Owned Subsidiary Receives an Order For A 10m3/Day (2,640 Gallons/Day) Sewage...
# Tesla''s mezcal is being resold for as high as $5K
# Brevo Adds Industry Leaders to Newly Formed Advisory Board
# Stocks to Watch Today: Tesla, Paramount, and Broadcom
# Selling A “Stupid” Tesla Cybertruck, Upgrading To Cadillac Lyriq
# Page 71
# Will Tesla do a phone? Morgan Stanley thinks so By Investing.com
# Vast former Bay Area Fry’s site lands real estate buyer from Florida
# Elon Musk’s Tesla pay package worth billions approved by shareholders
# Becoming a Real Estate Agent in Texas Just Got Simpler with ProctorFree from The CE Shop
# Elon Musk’s Tesla Pay Deal Worth Billions Approved By Shareholders | Bankrate
# Page 72
# Where Will Rivian Stock Be in 1 Year?
# Tesla Investors to Decide If Musk Is Worth $46 Billion - What’s News - WSJ Podcasts
# Will Tesla do a phone? Morgan Stanley thinks so
# Elon Musk wins back his huge Tesla payday in overwhelming shareholder vote
# Tesla investors back Musk''s $48B payday
# The Big Loser in Tesla’s Shareholder Vote Is Delaware
# Page 73
# Tesla Has a Trade-In Problem. It’s Going to Last Awhile.
# Tesla’s 2024 shareholder meeting: all the news about Elon Musk’s $50 billion payday
# Tesla shareholder sues Musk to return billions in alleged unlawful profits By Reuters
# How Tesla Shareholders Upheld Elon Musk’s Sky-High Pay
# Non-Foundation Tesla Cybertruck Coming Next Quarter, International Version Possible: Musk
# Tesla could come out on top after the EU cracks down on Chinese EVs
# 17,255 Shares in Tesla, Inc. (NASDAQ:TSLA) Bought by GLOBALT Investments LLC GA
# Page 74
# Musk wins pay approval but still faces Tesla''s floundering stock and rich valuation
# Elon Musk wins back his $44.9 billion Tesla pay package in shareholder vote
# How Elon Musk’s $44.9B Tesla pay package compares with the most generous plans for other U.S. CEOs -...
# Tesla shareholders back Musk pay package, Adobe''s outlook - what''s moving markets By Investing.com
# Interest in the Tesla cybertruck is high and low in these U.S. states
# Elon Musk wins Tesla shareholder vote for $56 billion pay package
# Page 75
# ''Don''t fire Steve Jobs'': Tesla analysts react to approval of Elon Musk''s pay package
# Elon Musk wins Tesla shareholder battle to keep his record-breaking pay
# Musk says Tesla shareholders voting for his pay by ‘wide margins’ | Fox 11 Tri Cities Fox 41 Yakima
# Elon Musk Says Optimus Will Make Tesla Worth Half Of The Entire S&P 500
# Raleigh Capital Management Inc. Has $399,000 Holdings in Tesla, Inc. (NASDAQ:TSLA)
# After disapproval, Elon Musk secures a whopping $56B pay cheque from Tesla shareholders
# Page 76
# With $56 billion approved for Musk, what Tesla does next is critical
# Here''s How Much Tesla Shares Are Up Since Elon Musk''s Original 2018 Pay Package Was Approved - Tesla...
# Page 77
# Here''s the Staggering Amount of Money Ford Loses on Each EV It Makes
# Page 78
# Tesla driver says he was using ‘self-drive’ system when car hit parked police vehicle
# EV Prices Climb as Tesla Prices Gain
# All The Tesla CEO''s Men (And Women): Elon Musk''s Inner Circle Lobbies Hard For His Pay Plan Ahead...
# Takes from 3 Tesla shareholders: Unenthusiastic yes to unequivocal no as Musk awaits vote on his pay
# Elon Musk says Tesla shareholders are voting to back his $46 billion pay package
# Page 79
# Elon Musk gets 77% approval from shareholders to get back his big, $44.9 billion Tesla pay package
# Page 80
# Elon Musk Teases Three New Vehicles At Tesla''s Annual Shareholder Meeting: More Affordable Model...
# vCom Solutions Named a Best Place to Work in the Bay Area for 17th Consecutive Year
# Page 81
# Bemax Inc. Announces Pre-Orders on Walmart for the Newly Designed Private Label Brand
# Stocks to Watch Thursday: Tesla, Broadcom, Virgin Galactic, Tyson, Adobe
# Elon Musk''s pay package approval was a ''mistake'' and Tesla needs to keep him in check, some...
# 25 series finales with the best last lines: From “Boy Meets World” to “Modern Family”
# Page 82
# Page 83
# Page 84
# EV startup Fisker files for bankruptcy, aims to sell assets
# Cherre and Upflex Partner to Help Landlords and Occupiers Unlock New Opportunities with Flex Data
# Tesla CEO Elon Musk Questions Apple-OpenAI Privacy
# Dead: Fisker Automotive
# As Tesla Supercharger plans stall, Ionna is going big on EV charging
# Elon Musk says Tesla pay deal vote is going in his favour
# Page 85
# Page 86
# Tesla reported to police in Sweden over alleged illegal electrical work By Reuters
# Tesla shareholders vote to give Elon Musk pay package worth $56bn
# CNBC Daily Open: Nasdaq record, Tesla future value?
# Why Tesla Stock Jumped Today
# Tesla Is Building A Cybertruck-Only Tunnel Under Its Texas Gigafactory
# Page 87
# Whatever Elon wants, Tesla gets
# Page 88
# Market Today: Tesla''s New Master Plan, Mustang Bio''s Breakthroug
# Tesla Shareholder Meeting: Elon Musk''s $56 Billion Pay Package Gets a Vote
# Page 89
# Report: BYD Will Supply LFP Batteries For Tesla''s Shanghai Megafactory
# Tesla Share Price Is Its Own Referendum on Musk
# Tesla shareholder vote on Elon Musk''s proposed $56 billion pay package heats up
# Page 90
# Harbour Investments Inc. Boosts Stock Holdings in Tesla, Inc. (NASDAQ:TSLA)
# Tesla’s stock should hit $2,600 in five years, says Cathie Wood’s Ark Invest
# Tesla Has a Trade-In Problem. It’s Going to Last a While.
# Future of Elon Musk and Tesla are on the line this week as shareholders vote on massive pay package
# Elon Musk wins back his $44.9B Tesla pay package in shareholder vote
# Musk Says Tesla Shareholders Voting For His Pay Package By ''Wide Margins''
# Page 91
# Tesla''s shareholder vote is about more than Elon Musk''s money
# CLS Health Launches New Multi-Specialty Building, Expanding Healthcare Access in Clear Lake
# Tesla''s Performance Since Musk''s Compensation Package Was First Approved in 2018
# Winston Products Welcomes Twisted Goat to Its Family of Innovative Brands
# Page 92
# Ecotrader: Revolutionizing Renewable Energy Investments with RWA Tokenization
# Shanghai allows Tesla to carry out Full Self-Driving pilot
# Analyst predicts Tesla''s Elon Musk may create Apple rival
# Trump''s ''Huge Fan'' Status of Tesla Cybertruck Fuels Growing Alliance with Elon Musk - EconoTimes
# Musk says Tesla shareholders voting yes for his $56 billion pay package
# Page 93
# Elon Musk Claims the New Tesla Roadster Will Be Able to Fly - EconoTimes
# It''s all roses and rainbows today in Austin, one Tesla analyst says of Musk''s mega payday vote
# Should Tesla pay Elon Musk $45bn? The shareholders will decide
# Page 94
# Analysts reset Tesla stock outlooks after Musk’s $56 billion win
# Page 95
# Why Tesla Stock Jumped Today | The Motley Fool
# Future of Musk and Tesla on the line as shareholders vote on massive pay plan
# Page 96
# Tesla Cybertruck Increased The Average EV Price In The U.S. In May
# Page 97
# Tesla Rival Rivian Opens ''Space'' In Austin Merely 14 Miles Away From Giga Texas - Rivian Automotive...
# Natural Scientific: A Game-Changer in the Nutritional Supplement Industry
# Tesla CEO Musk’s pay package gets support from 77% of votes at investor meet
# Watch The 2024 Tesla Shareholder Vote Livestream Here
# Let’s speculate wildly about Tesla’s three mystery vehicles
# Page 98
# Tesla''s incorporation move to Texas sparks legal battles amid shareholder unrest | Invezz
# Page 99
# Page 100
# Hot Or Not: Tesla Cybertruck Wraps You Can''t Look Away From
# Is Elon Musk worth his $56bn Tesla pay package?
# Elon Musk Wins Back His $44.9 Billion Tesla Pay Package in Shareholder Vote
# Elon Musk''s $56B Tesla pay package in the balance as shareholders hold meeting
# Elon Musk’s multi-billion paycheck just got approved by stockholders. That could be a fraction of...
# Page 101
# Size of articles:415
